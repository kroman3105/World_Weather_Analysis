# %%
from citipy import citipy
import requests
from config import weather_api_key
import numpy as np
import pandas as pd

# %%
#3. Create a new set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(-90,90,size=2000)
lngs = np.random.uniform(-90,90,size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
#4. Get the nearest city using the citypy module
cities = []
# Identify the nearest city for each latitiude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 785

# %%
#5. starting URL for Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#6. Retrieve Latitude, Longitude, Max Temperature, Percent Humidity, Percent Cloudiness, Wind Spped, Weather description
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging
print('Beginning Data Retrieval    ')
print('----------------------------')

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set the numbers and the city
    print(f"Processing Record {record_count} of Set {set_count}|{city}")
    
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities
    try:
        # parse the JSON and retrive the data
        city_weather = requests.get(city_url).json()
        # parse out the needed data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        
        # Append the city information into city_data list
        city_data.append({'City': city.title(),
                         'Country': city_country,
                          'Lat': city_lat,
                         'Lng': city_lng,
                         'Max Temp': city_max_temp,
                         'Humidity': city_humidity,
                         'Cloudiness': city_clouds,
                         'Wind Speed': city_wind,
                         'Current Description': city_description})
# if an error is experienced, skip the city
    except:
        print('City not found. Skipping...')
        pass
    
# Indicate the data loading is complete
print("--------------------------")
print("Data retrieval complete   ")
print("--------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1|ushuaia
# Processing Record 2 of Set 1|nanortalik
# Processing Record 3 of Set 1|amderma
# City not found. Skipping...
# Processing Record 4 of Set 1|ibra
# Processing Record 5 of Set 1|cape town
# Processing Record 6 of Set 1|jamestown
# Processing Record 7 of Set 1|kavaratti
# Processing Record 8 of Set 1|sumbe
# Processing Record 9 of Set 1|hofn
# Processing Record 10 of Set 1|chuy
# Processing Record 11 of Set 1|hermanus
# Processing Record 12 of Set 1|kansanshi
# Processing Record 13 of Set 1|kruisfontein
# Processing Record 14 of Set 1|namibe
# Processing Record 15 of Set 1|benguela
# Processing Record 16 of Set 1|sao filipe
# Processing Record 17 of Set 1|mar del plata
# Processing Record 18 of Set 1|honningsvag
# Processing Record 19 of Set 1|chapais
# Processing Record 20 of Set 1|nioro
# Processing Record 21 of Set 1|sorland
# Processing Record 22 of Set 1|yangambi
# Processing Record 23 of Set 1|saint-augustin
# Processing Record 24 of Set 1|busselton
# Processing Record 25 of Set 1|viligili
# City not found. Skipping...
# Processing Record 26 of Set 1|luderitz
# Processing Record 27 of Set 1|saint george
# Processing Record 28 of Set 1|port alfred
# Processing Record 29 of Set 1|abu samrah
# Processing Record 30 of Set 1|eydhafushi
# Processing Record 31 of Set 1|pucallpa
# Processing Record 32 of Set 1|torbay
# Processing Record 33 of Set 1|lavello
# Processing Record 34 of Set 1|souillac
# Processing Record 35 of Set 1|george town
# Processing Record 36 of Set 1|taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1|weligama
# Processing Record 38 of Set 1|nara
# Processing Record 39 of Set 1|malyn
# Processing Record 40 of Set 1|barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 1|adre
# Processing Record 42 of Set 1|dudinka
# Processing Record 43 of Set 1|ostersund
# Processing Record 44 of Set 1|toktogul
# Processing Record 45 of Set 1|umm kaddadah
# Processing Record 46 of Set 1|saldanha
# Processing Record 47 of Set 1|dikson
# Processing Record 48 of Set 1|sompeta
# Processing Record 49 of Set 1|arlit
# Processing Record 50 of Set 1|vardo
# Processing Record 1 of Set 2|ribeira grande
# Processing Record 2 of Set 2|muros
# Processing Record 3 of Set 2|bredasdorp
# Processing Record 4 of Set 2|bani walid
# Processing Record 5 of Set 2|abha
# Processing Record 6 of Set 2|arraial do cabo
# Processing Record 7 of Set 2|hauterive
# Processing Record 8 of Set 2|behbahan
# Processing Record 9 of Set 2|upernavik
# Processing Record 10 of Set 2|spasskoye
# Processing Record 11 of Set 2|edd
# Processing Record 12 of Set 2|georgetown
# Processing Record 13 of Set 2|hithadhoo
# Processing Record 14 of Set 2|luanda
# Processing Record 15 of Set 2|dingle
# Processing Record 16 of Set 2|axim
# Processing Record 17 of Set 2|bambous virieux
# Processing Record 18 of Set 2|mashhad
# Processing Record 19 of Set 2|lagoa
# Processing Record 20 of Set 2|coihaique
# Processing Record 21 of Set 2|victoria
# Processing Record 22 of Set 2|belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 2|punta arenas
# Processing Record 24 of Set 2|khakhea
# Processing Record 25 of Set 2|santa rosa
# Processing Record 26 of Set 2|quelimane
# Processing Record 27 of Set 2|bure
# Processing Record 28 of Set 2|brae
# Processing Record 29 of Set 2|aksu
# Processing Record 30 of Set 2|goderich
# Processing Record 31 of Set 2|east london
# Processing Record 32 of Set 2|lamu
# Processing Record 33 of Set 2|saint-andre-les-vergers
# Processing Record 34 of Set 2|fereydunshahr
# Processing Record 35 of Set 2|mahebourg
# Processing Record 36 of Set 2|tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 2|korla
# Processing Record 38 of Set 2|umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 2|lethem
# Processing Record 40 of Set 2|sisimiut
# Processing Record 41 of Set 2|rio bueno
# Processing Record 42 of Set 2|kapoeta
# Processing Record 43 of Set 2|riachao das neves
# Processing Record 44 of Set 2|port elizabeth
# Processing Record 45 of Set 2|saint-louis
# Processing Record 46 of Set 2|emba
# Processing Record 47 of Set 2|moskovskiy
# Processing Record 48 of Set 2|barawe
# City not found. Skipping...
# Processing Record 49 of Set 2|illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 2|qaanaaq
# Processing Record 1 of Set 3|carnarvon
# Processing Record 2 of Set 3|cidreira
# Processing Record 3 of Set 3|paucartambo
# City not found. Skipping...
# Processing Record 4 of Set 3|monrovia
# Processing Record 5 of Set 3|raudeberg
# Processing Record 6 of Set 3|tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 3|ratnagiri
# Processing Record 8 of Set 3|berbera
# Processing Record 9 of Set 3|mamlyutka
# Processing Record 10 of Set 3|bosconia
# Processing Record 11 of Set 3|areka
# Processing Record 12 of Set 3|hamilton
# Processing Record 13 of Set 3|cherdyn
# Processing Record 14 of Set 3|rawson
# Processing Record 15 of Set 3|clyde river
# Processing Record 16 of Set 3|grand gaube
# Processing Record 17 of Set 3|vikulovo
# Processing Record 18 of Set 3|nantucket
# Processing Record 19 of Set 3|sur
# Processing Record 20 of Set 3|licata
# Processing Record 21 of Set 3|ipanema
# Processing Record 22 of Set 3|marsh harbour
# Processing Record 23 of Set 3|longyearbyen
# Processing Record 24 of Set 3|san cristobal
# Processing Record 25 of Set 3|klaksvik
# Processing Record 26 of Set 3|narok
# Processing Record 27 of Set 3|margate
# Processing Record 28 of Set 3|soyo
# Processing Record 29 of Set 3|binghamton
# Processing Record 30 of Set 3|alta floresta
# Processing Record 31 of Set 3|saint-pierre
# Processing Record 32 of Set 3|ostrovnoy
# Processing Record 33 of Set 3|saint-philippe
# Processing Record 34 of Set 3|marsa matruh
# Processing Record 35 of Set 3|san miguel
# Processing Record 36 of Set 3|mananjary
# Processing Record 37 of Set 3|codrington
# Processing Record 38 of Set 3|aquiraz
# Processing Record 39 of Set 3|neuquen
# Processing Record 40 of Set 3|boundiali
# Processing Record 41 of Set 3|north tonawanda
# Processing Record 42 of Set 3|tiznit
# Processing Record 43 of Set 3|zbarazh
# Processing Record 44 of Set 3|coihueco
# Processing Record 45 of Set 3|lasa
# Processing Record 46 of Set 3|ushtobe
# Processing Record 47 of Set 3|lagos
# Processing Record 48 of Set 3|gat
# Processing Record 49 of Set 3|ponta do sol
# Processing Record 50 of Set 3|turbat
# Processing Record 1 of Set 4|mitsamiouli
# Processing Record 2 of Set 4|vila velha
# Processing Record 3 of Set 4|vysokaya gora
# Processing Record 4 of Set 4|chicama
# Processing Record 5 of Set 4|simbakoro
# Processing Record 6 of Set 4|sao joao da barra
# Processing Record 7 of Set 4|paamiut
# Processing Record 8 of Set 4|xique-xique
# Processing Record 9 of Set 4|cotonou
# Processing Record 10 of Set 4|srikakulam
# Processing Record 11 of Set 4|at-bashi
# Processing Record 12 of Set 4|palora
# Processing Record 13 of Set 4|charlestown
# Processing Record 14 of Set 4|guajara-mirim
# City not found. Skipping...
# Processing Record 15 of Set 4|kuryk
# Processing Record 16 of Set 4|cheuskiny
# City not found. Skipping...
# Processing Record 17 of Set 4|eskasem
# City not found. Skipping...
# Processing Record 18 of Set 4|yalchiki
# City not found. Skipping...
# Processing Record 19 of Set 4|buqayq
# City not found. Skipping...
# Processing Record 20 of Set 4|atasu
# Processing Record 21 of Set 4|grand-santi
# Processing Record 22 of Set 4|karistos
# City not found. Skipping...
# Processing Record 23 of Set 4|richards bay
# Processing Record 24 of Set 4|yar-sale
# Processing Record 25 of Set 4|aktash
# Processing Record 26 of Set 4|umm durman
# City not found. Skipping...
# Processing Record 27 of Set 4|mogadouro
# Processing Record 28 of Set 4|fez
# Processing Record 29 of Set 4|port-cartier
# Processing Record 30 of Set 4|aflu
# City not found. Skipping...
# Processing Record 31 of Set 4|nuuk
# Processing Record 32 of Set 4|salobrena
# Processing Record 33 of Set 4|faya
# Processing Record 34 of Set 4|tabuk
# Processing Record 35 of Set 4|calabozo
# Processing Record 36 of Set 4|castro
# Processing Record 37 of Set 4|dagana
# Processing Record 38 of Set 4|san antonio
# Processing Record 39 of Set 4|jizan
# Processing Record 40 of Set 4|goundam
# Processing Record 41 of Set 4|taltal
# Processing Record 42 of Set 4|ilinskiy
# Processing Record 43 of Set 4|villazon
# Processing Record 44 of Set 4|quirinopolis
# Processing Record 45 of Set 4|abu kamal
# Processing Record 46 of Set 4|coutances
# Processing Record 47 of Set 4|sambava
# Processing Record 48 of Set 4|coquimbo
# Processing Record 49 of Set 4|bubaque
# Processing Record 50 of Set 4|youghal
# Processing Record 1 of Set 5|havoysund
# Processing Record 2 of Set 5|sinnamary
# Processing Record 3 of Set 5|maniitsoq
# Processing Record 4 of Set 5|kohtla-jarve
# Processing Record 5 of Set 5|roslavl
# Processing Record 6 of Set 5|mantua
# Processing Record 7 of Set 5|rovaniemi
# Processing Record 8 of Set 5|mopti
# Processing Record 9 of Set 5|vila franca do campo
# Processing Record 10 of Set 5|karkaralinsk
# City not found. Skipping...
# Processing Record 11 of Set 5|lebu
# Processing Record 12 of Set 5|vila vicosa
# Processing Record 13 of Set 5|neon soulion
# Processing Record 14 of Set 5|grindavik
# Processing Record 15 of Set 5|nueva loja
# Processing Record 16 of Set 5|poienile de sub munte
# Processing Record 17 of Set 5|asyut
# Processing Record 18 of Set 5|rumboci
# Processing Record 19 of Set 5|hobyo
# Processing Record 20 of Set 5|touros
# Processing Record 21 of Set 5|praia da vitoria
# Processing Record 22 of Set 5|togur
# Processing Record 23 of Set 5|santiago de compostela
# Processing Record 24 of Set 5|west milford
# Processing Record 25 of Set 5|kosh-agach
# Processing Record 26 of Set 5|bandarbeyla
# Processing Record 27 of Set 5|cayenne
# Processing Record 28 of Set 5|moroni
# Processing Record 29 of Set 5|hambantota
# Processing Record 30 of Set 5|fort wellington
# Processing Record 31 of Set 5|nalut
# Processing Record 32 of Set 5|batticaloa
# Processing Record 33 of Set 5|santo andre
# Processing Record 34 of Set 5|convencion
# City not found. Skipping...
# Processing Record 35 of Set 5|saint-paul
# Processing Record 36 of Set 5|maymanak
# City not found. Skipping...
# Processing Record 37 of Set 5|lodwar
# Processing Record 38 of Set 5|matay
# Processing Record 39 of Set 5|saint-raymond
# Processing Record 40 of Set 5|guisa
# Processing Record 41 of Set 5|pimentel
# Processing Record 42 of Set 5|paradwip
# City not found. Skipping...
# Processing Record 43 of Set 5|iracoubo
# Processing Record 44 of Set 5|uruzgan
# Processing Record 45 of Set 5|saint-francois
# Processing Record 46 of Set 5|timra
# Processing Record 47 of Set 5|bischwiller
# Processing Record 48 of Set 5|port hawkesbury
# Processing Record 49 of Set 5|attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 5|marcona
# City not found. Skipping...
# Processing Record 1 of Set 6|puerto maldonado
# Processing Record 2 of Set 6|kot addu
# Processing Record 3 of Set 6|traverse city
# Processing Record 4 of Set 6|malko tarnovo
# Processing Record 5 of Set 6|serowe
# Processing Record 6 of Set 6|dolores
# Processing Record 7 of Set 6|salalah
# Processing Record 8 of Set 6|rhenen
# Processing Record 9 of Set 6|agirish
# Processing Record 10 of Set 6|nadym
# Processing Record 11 of Set 6|rajakhera
# Processing Record 12 of Set 6|presidencia roque saenz pena
# Processing Record 13 of Set 6|urbano santos
# Processing Record 14 of Set 6|encrucijada
# Processing Record 15 of Set 6|porto santo
# Processing Record 16 of Set 6|kholmogory
# Processing Record 17 of Set 6|rudnichnyy
# Processing Record 18 of Set 6|hosakote
# Processing Record 19 of Set 6|olafsvik
# Processing Record 20 of Set 6|pangnirtung
# Processing Record 21 of Set 6|karabulak
# Processing Record 22 of Set 6|kathmandu
# Processing Record 23 of Set 6|nampula
# Processing Record 24 of Set 6|sayyan
# Processing Record 25 of Set 6|mozarlandia
# Processing Record 26 of Set 6|santa maria
# Processing Record 27 of Set 6|guasdualito
# Processing Record 28 of Set 6|tasiilaq
# Processing Record 29 of Set 6|frolovo
# Processing Record 30 of Set 6|vestmanna
# Processing Record 31 of Set 6|hualmay
# Processing Record 32 of Set 6|laguna
# Processing Record 33 of Set 6|aguilas
# Processing Record 34 of Set 6|narsaq
# Processing Record 35 of Set 6|tinaquillo
# Processing Record 36 of Set 6|poshtove
# Processing Record 37 of Set 6|lar gerd
# City not found. Skipping...
# Processing Record 38 of Set 6|scarborough
# Processing Record 39 of Set 6|toliary
# City not found. Skipping...
# Processing Record 40 of Set 6|matagami
# Processing Record 41 of Set 6|kaputa
# Processing Record 42 of Set 6|nova olimpia
# Processing Record 43 of Set 6|marzuq
# Processing Record 44 of Set 6|wilmington
# Processing Record 45 of Set 6|huarmey
# Processing Record 46 of Set 6|gander
# Processing Record 47 of Set 6|sao francisco do sul
# Processing Record 48 of Set 6|azimur
# City not found. Skipping...
# Processing Record 49 of Set 6|angatuba
# Processing Record 50 of Set 6|polunochnoye
# Processing Record 1 of Set 7|lieksa
# Processing Record 2 of Set 7|agadir
# Processing Record 3 of Set 7|padang
# Processing Record 4 of Set 7|kegayli
# City not found. Skipping...
# Processing Record 5 of Set 7|tshikapa
# Processing Record 6 of Set 7|saint-georges
# Processing Record 7 of Set 7|kamenka
# Processing Record 8 of Set 7|manadhoo
# Processing Record 9 of Set 7|necochea
# Processing Record 10 of Set 7|adrar
# Processing Record 11 of Set 7|manbij
# Processing Record 12 of Set 7|sao geraldo do araguaia
# Processing Record 13 of Set 7|geraldton
# Processing Record 14 of Set 7|la roche-sur-yon
# Processing Record 15 of Set 7|altay
# Processing Record 16 of Set 7|tocopilla
# Processing Record 17 of Set 7|shelburne
# Processing Record 18 of Set 7|harper
# Processing Record 19 of Set 7|bathsheba
# Processing Record 20 of Set 7|umm lajj
# Processing Record 21 of Set 7|pabrade
# Processing Record 22 of Set 7|xuddur
# Processing Record 23 of Set 7|sao felix do xingu
# Processing Record 24 of Set 7|tazovskiy
# Processing Record 25 of Set 7|barddhaman
# Processing Record 26 of Set 7|iqaluit
# Processing Record 27 of Set 7|bocana de paiwas
# Processing Record 28 of Set 7|nefteyugansk
# Processing Record 29 of Set 7|black river
# Processing Record 30 of Set 7|mont-de-marsan
# Processing Record 31 of Set 7|takoradi
# Processing Record 32 of Set 7|luba
# Processing Record 33 of Set 7|krasnogorskoye
# Processing Record 34 of Set 7|birao
# Processing Record 35 of Set 7|puerto narino
# Processing Record 36 of Set 7|manyana
# Processing Record 37 of Set 7|palmas
# Processing Record 38 of Set 7|ramanuj ganj
# Processing Record 39 of Set 7|rocha
# Processing Record 40 of Set 7|kachikau
# City not found. Skipping...
# Processing Record 41 of Set 7|san carlos del zulia
# Processing Record 42 of Set 7|bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 7|kamarion
# Processing Record 44 of Set 7|veraval
# Processing Record 45 of Set 7|bengkulu
# Processing Record 46 of Set 7|baglung
# Processing Record 47 of Set 7|husavik
# Processing Record 48 of Set 7|talnakh
# Processing Record 49 of Set 7|grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 7|viedma
# Processing Record 1 of Set 8|liwale
# Processing Record 2 of Set 8|meulaboh
# Processing Record 3 of Set 8|shalya
# Processing Record 4 of Set 8|saint anthony
# Processing Record 5 of Set 8|franklin
# Processing Record 6 of Set 8|kayes
# Processing Record 7 of Set 8|trujillo
# Processing Record 8 of Set 8|marawi
# Processing Record 9 of Set 8|abalak
# Processing Record 10 of Set 8|barroso
# Processing Record 11 of Set 8|hornepayne
# Processing Record 12 of Set 8|birzai
# Processing Record 13 of Set 8|maracacume
# Processing Record 14 of Set 8|trairi
# Processing Record 15 of Set 8|puerto leguizamo
# Processing Record 16 of Set 8|bhind
# Processing Record 17 of Set 8|isola del liri
# Processing Record 18 of Set 8|birjand
# Processing Record 19 of Set 8|okoneshnikovo
# Processing Record 20 of Set 8|formosa
# Processing Record 21 of Set 8|tucurui
# Processing Record 22 of Set 8|tutoia
# Processing Record 23 of Set 8|mpanda
# Processing Record 24 of Set 8|leh
# Processing Record 25 of Set 8|tignere
# Processing Record 26 of Set 8|maltahohe
# Processing Record 27 of Set 8|port-gentil
# Processing Record 28 of Set 8|eldorado
# Processing Record 29 of Set 8|cacule
# Processing Record 30 of Set 8|sovetskiy
# Processing Record 31 of Set 8|gornopravdinsk
# Processing Record 32 of Set 8|desa
# Processing Record 33 of Set 8|sarai naurang
# Processing Record 34 of Set 8|valparaiso
# Processing Record 35 of Set 8|coria
# Processing Record 36 of Set 8|boffa
# Processing Record 37 of Set 8|buraydah
# Processing Record 38 of Set 8|ilulissat
# Processing Record 39 of Set 8|kozhva
# Processing Record 40 of Set 8|rostovka
# Processing Record 41 of Set 8|ayolas
# Processing Record 42 of Set 8|puerto lopez
# Processing Record 43 of Set 8|nikki
# Processing Record 44 of Set 8|villarrica
# Processing Record 45 of Set 8|aras
# Processing Record 46 of Set 8|mount darwin
# Processing Record 47 of Set 8|kangaatsiaq
# Processing Record 48 of Set 8|belmonte
# Processing Record 49 of Set 8|maragogi
# Processing Record 50 of Set 8|huancayo
# Processing Record 1 of Set 9|pelym
# Processing Record 2 of Set 9|khromtau
# Processing Record 3 of Set 9|zhezkazgan
# Processing Record 4 of Set 9|aden
# Processing Record 5 of Set 9|westpunt
# City not found. Skipping...
# Processing Record 6 of Set 9|dekar
# Processing Record 7 of Set 9|kalaleh
# Processing Record 8 of Set 9|vila do maio
# Processing Record 9 of Set 9|farafangana
# Processing Record 10 of Set 9|andenes
# Processing Record 11 of Set 9|lindi
# Processing Record 12 of Set 9|khorramshahr
# Processing Record 13 of Set 9|teguise
# Processing Record 14 of Set 9|millerovo
# Processing Record 15 of Set 9|bowling green
# Processing Record 16 of Set 9|kingsland
# Processing Record 17 of Set 9|bestobe
# Processing Record 18 of Set 9|wai
# Processing Record 19 of Set 9|pisco
# Processing Record 20 of Set 9|parauna
# Processing Record 21 of Set 9|chardara
# Processing Record 22 of Set 9|chimoio
# Processing Record 23 of Set 9|siguiri
# Processing Record 24 of Set 9|puerto asis
# Processing Record 25 of Set 9|verkhnetulomskiy
# Processing Record 26 of Set 9|lubango
# Processing Record 27 of Set 9|tornio
# Processing Record 28 of Set 9|hunza
# City not found. Skipping...
# Processing Record 29 of Set 9|nizwa
# Processing Record 30 of Set 9|beira
# Processing Record 31 of Set 9|boddam
# Processing Record 32 of Set 9|springdale
# Processing Record 33 of Set 9|owensboro
# Processing Record 34 of Set 9|mandali
# Processing Record 35 of Set 9|bonavista
# Processing Record 36 of Set 9|andros town
# Processing Record 37 of Set 9|frederico westphalen
# Processing Record 38 of Set 9|erzurum
# Processing Record 39 of Set 9|sabha
# Processing Record 40 of Set 9|vertientes
# Processing Record 41 of Set 9|latur
# Processing Record 42 of Set 9|morrope
# Processing Record 43 of Set 9|roald
# Processing Record 44 of Set 9|mweka
# Processing Record 45 of Set 9|salinas
# Processing Record 46 of Set 9|manakara
# Processing Record 47 of Set 9|adra
# Processing Record 48 of Set 9|gayny
# Processing Record 49 of Set 9|sortland
# Processing Record 50 of Set 9|challapata
# Processing Record 1 of Set 10|berlevag
# Processing Record 2 of Set 10|prainha
# Processing Record 3 of Set 10|abu jubayhah
# City not found. Skipping...
# Processing Record 4 of Set 10|rio grande
# Processing Record 5 of Set 10|kamo
# Processing Record 6 of Set 10|saint-leu
# Processing Record 7 of Set 10|kazalinsk
# City not found. Skipping...
# Processing Record 8 of Set 10|zhanaozen
# Processing Record 9 of Set 10|akniste
# Processing Record 10 of Set 10|birin
# Processing Record 11 of Set 10|rosarno
# Processing Record 12 of Set 10|leticia
# Processing Record 13 of Set 10|grande-riviere
# City not found. Skipping...
# Processing Record 14 of Set 10|martvili
# Processing Record 15 of Set 10|mirnyy
# Processing Record 16 of Set 10|sembe
# Processing Record 17 of Set 10|arkhangelsk
# Processing Record 18 of Set 10|pangoa
# Processing Record 19 of Set 10|perpignan
# Processing Record 20 of Set 10|makat
# Processing Record 21 of Set 10|kumo
# Processing Record 22 of Set 10|ewo
# Processing Record 23 of Set 10|abnub
# Processing Record 24 of Set 10|vandoeuvre-les-nancy
# Processing Record 25 of Set 10|bokovskaya
# Processing Record 26 of Set 10|srivardhan
# Processing Record 27 of Set 10|porto novo
# Processing Record 28 of Set 10|rudbar
# Processing Record 29 of Set 10|bargal
# City not found. Skipping...
# Processing Record 30 of Set 10|rorvik
# Processing Record 31 of Set 10|saint-joseph
# Processing Record 32 of Set 10|taunsa
# Processing Record 33 of Set 10|knysna
# Processing Record 34 of Set 10|kumla
# Processing Record 35 of Set 10|jalu
# Processing Record 36 of Set 10|barbar
# City not found. Skipping...
# Processing Record 37 of Set 10|rio gallegos
# Processing Record 38 of Set 10|isiro
# Processing Record 39 of Set 10|tunduru
# City not found. Skipping...
# Processing Record 40 of Set 10|sawakin
# Processing Record 41 of Set 10|northampton
# Processing Record 42 of Set 10|wadi musa
# Processing Record 43 of Set 10|walvis bay
# Processing Record 44 of Set 10|la maddalena
# Processing Record 45 of Set 10|acari
# Processing Record 46 of Set 10|boa vista
# Processing Record 47 of Set 10|achisay
# City not found. Skipping...
# Processing Record 48 of Set 10|woodstock
# Processing Record 49 of Set 10|henties bay
# Processing Record 50 of Set 10|qunduz
# Processing Record 1 of Set 11|maua
# Processing Record 2 of Set 11|gonbad-e qabus
# Processing Record 3 of Set 11|vestmannaeyjar
# Processing Record 4 of Set 11|wana
# Processing Record 5 of Set 11|carutapera
# Processing Record 6 of Set 11|daudnagar
# Processing Record 7 of Set 11|beremend
# Processing Record 8 of Set 11|kargasok
# Processing Record 9 of Set 11|lesnoy
# Processing Record 10 of Set 11|puerto baquerizo moreno
# Processing Record 11 of Set 11|altamira
# Processing Record 12 of Set 11|dalvik
# Processing Record 13 of Set 11|jumla
# Processing Record 14 of Set 11|dhadar
# Processing Record 15 of Set 11|riyadh
# Processing Record 16 of Set 11|prado
# Processing Record 17 of Set 11|talcher
# Processing Record 18 of Set 11|egersund
# Processing Record 19 of Set 11|los llanos de aridane
# Processing Record 20 of Set 11|oistins
# Processing Record 21 of Set 11|ovalle
# Processing Record 22 of Set 11|luau
# Processing Record 23 of Set 11|libreville
# Processing Record 24 of Set 11|omboue
# Processing Record 25 of Set 11|simplicio mendes
# Processing Record 26 of Set 11|ballina
# Processing Record 27 of Set 11|the valley
# Processing Record 28 of Set 11|santa vitoria do palmar
# Processing Record 29 of Set 11|qaqortoq
# Processing Record 30 of Set 11|mahanoro
# Processing Record 31 of Set 11|marystown
# Processing Record 32 of Set 11|muravlenko
# Processing Record 33 of Set 11|soanierana ivongo
# Processing Record 34 of Set 11|morondava
# Processing Record 35 of Set 11|shetpe
# Processing Record 36 of Set 11|vyartsilya
# Processing Record 37 of Set 11|canandaigua
# Processing Record 38 of Set 11|cauquenes
# Processing Record 39 of Set 11|oyem
# Processing Record 40 of Set 11|tiassale
# Processing Record 41 of Set 11|behshahr
# Processing Record 42 of Set 11|kushmurun
# Processing Record 43 of Set 11|dharchula
# Processing Record 44 of Set 11|killybegs
# Processing Record 45 of Set 11|baihar
# Processing Record 46 of Set 11|ndola
# Processing Record 47 of Set 11|inhambane
# Processing Record 48 of Set 11|ormara
# Processing Record 49 of Set 11|nouakchott
# Processing Record 50 of Set 11|illapel
# Processing Record 1 of Set 12|kpandae
# Processing Record 2 of Set 12|calvinia
# Processing Record 3 of Set 12|sistranda
# Processing Record 4 of Set 12|salekhard
# Processing Record 5 of Set 12|kaoma
# Processing Record 6 of Set 12|zabid
# Processing Record 7 of Set 12|sinkat
# City not found. Skipping...
# Processing Record 8 of Set 12|paramonga
# Processing Record 9 of Set 12|cumaribo
# City not found. Skipping...
# Processing Record 10 of Set 12|sabzevar
# Processing Record 11 of Set 12|iglesias
# Processing Record 12 of Set 12|una
# Processing Record 13 of Set 12|high rock
# Processing Record 14 of Set 12|zheleznodorozhnyy
# Processing Record 15 of Set 12|sandnessjoen
# Processing Record 16 of Set 12|kidal
# Processing Record 17 of Set 12|koutsouras
# Processing Record 18 of Set 12|seredka
# Processing Record 19 of Set 12|skjervoy
# Processing Record 20 of Set 12|mosetse
# Processing Record 21 of Set 12|yershichi
# Processing Record 22 of Set 12|zaraza
# Processing Record 23 of Set 12|kalugumalai
# Processing Record 24 of Set 12|kant
# Processing Record 25 of Set 12|sidi bu zayd
# City not found. Skipping...
# Processing Record 26 of Set 12|grand-lahou
# Processing Record 27 of Set 12|asilah
# Processing Record 28 of Set 12|lichtenburg
# Processing Record 29 of Set 12|camacupa
# Processing Record 30 of Set 12|bonanza
# Processing Record 31 of Set 12|ancud
# Processing Record 32 of Set 12|vigrestad
# Processing Record 33 of Set 12|bagotville
# Processing Record 34 of Set 12|maldonado
# Processing Record 35 of Set 12|amapa
# Processing Record 36 of Set 12|cockburn town
# Processing Record 37 of Set 12|svarstad
# Processing Record 38 of Set 12|sturgeon falls
# Processing Record 39 of Set 12|plettenberg bay
# Processing Record 40 of Set 12|ceuta
# Processing Record 41 of Set 12|opuwo
# Processing Record 42 of Set 12|gambo
# Processing Record 43 of Set 12|salinopolis
# Processing Record 44 of Set 12|annau
# Processing Record 45 of Set 12|dapaong
# Processing Record 46 of Set 12|clarence town
# Processing Record 47 of Set 12|melioratorov
# Processing Record 48 of Set 12|bundi
# Processing Record 49 of Set 12|awjilah
# Processing Record 50 of Set 12|khorixas
# Processing Record 1 of Set 13|piranhas
# Processing Record 2 of Set 13|zapadnaya dvina
# Processing Record 3 of Set 13|mecca
# Processing Record 4 of Set 13|caraballeda
# Processing Record 5 of Set 13|mustasaari
# Processing Record 6 of Set 13|nicosia
# Processing Record 7 of Set 13|chambersburg
# Processing Record 8 of Set 13|rumphi
# Processing Record 9 of Set 13|tahta
# Processing Record 10 of Set 13|gisenyi
# Processing Record 11 of Set 13|constantine
# Processing Record 12 of Set 13|tundla
# Processing Record 13 of Set 13|addis zemen
# City not found. Skipping...
# Processing Record 14 of Set 13|harqalah
# Processing Record 15 of Set 13|mosquera
# Processing Record 16 of Set 13|damietta
# Processing Record 17 of Set 13|pitimbu
# Processing Record 18 of Set 13|bocas del toro
# Processing Record 19 of Set 13|erdemli
# Processing Record 20 of Set 13|karera
# Processing Record 21 of Set 13|kedrovyy
# Processing Record 22 of Set 13|sundsvall
# Processing Record 23 of Set 13|gazojak
# Processing Record 24 of Set 13|issenye
# Processing Record 25 of Set 13|santa isabel do rio negro
# Processing Record 26 of Set 13|maun
# Processing Record 27 of Set 13|buy
# Processing Record 28 of Set 13|velikiy ustyug
# Processing Record 29 of Set 13|eyl
# Processing Record 30 of Set 13|banepa
# Processing Record 31 of Set 13|joshimath
# Processing Record 32 of Set 13|surt
# Processing Record 33 of Set 13|oktyabrskiy
# Processing Record 34 of Set 13|teguldet
# Processing Record 35 of Set 13|lipin bor
# Processing Record 36 of Set 13|kaffrine
# Processing Record 37 of Set 13|bousso
# Processing Record 38 of Set 13|chinhoyi
# Processing Record 39 of Set 13|saravena
# Processing Record 40 of Set 13|grado
# Processing Record 41 of Set 13|amboise
# Processing Record 42 of Set 13|imbituba
# Processing Record 43 of Set 13|ambodifototra
# City not found. Skipping...
# Processing Record 44 of Set 13|praia
# Processing Record 45 of Set 13|nador
# Processing Record 46 of Set 13|keuruu
# Processing Record 47 of Set 13|termoli
# Processing Record 48 of Set 13|bajo baudo
# City not found. Skipping...
# Processing Record 49 of Set 13|bournemouth
# Processing Record 50 of Set 13|chiredzi
# Processing Record 1 of Set 14|virarajendrapet
# Processing Record 2 of Set 14|upata
# Processing Record 3 of Set 14|kuchera
# Processing Record 4 of Set 14|darab
# Processing Record 5 of Set 14|polis
# Processing Record 6 of Set 14|pozo colorado
# Processing Record 7 of Set 14|lerwick
# Processing Record 8 of Set 14|kondinskoye
# Processing Record 9 of Set 14|beyneu
# Processing Record 10 of Set 14|arrifes
# Processing Record 11 of Set 14|de panne
# Processing Record 12 of Set 14|ciudad real
# Processing Record 13 of Set 14|kapchorwa
# Processing Record 14 of Set 14|lazurne
# Processing Record 15 of Set 14|cacador
# Processing Record 16 of Set 14|ciudad bolivar
# Processing Record 17 of Set 14|doha
# Processing Record 18 of Set 14|prieska
# Processing Record 19 of Set 14|arti
# Processing Record 20 of Set 14|oxford
# Processing Record 21 of Set 14|sahrak
# City not found. Skipping...
# Processing Record 22 of Set 14|bar harbor
# Processing Record 23 of Set 14|pratapgarh
# Processing Record 24 of Set 14|malanville
# Processing Record 25 of Set 14|lapua
# Processing Record 26 of Set 14|aliwal north
# Processing Record 27 of Set 14|escanaba
# Processing Record 28 of Set 14|san carlos de bariloche
# Processing Record 29 of Set 14|bur gabo
# City not found. Skipping...
# Processing Record 30 of Set 14|mahibadhoo
# Processing Record 31 of Set 14|wahran
# City not found. Skipping...
# Processing Record 32 of Set 14|mangai
# Processing Record 33 of Set 14|kynsperk nad ohri
# Processing Record 34 of Set 14|camacha
# Processing Record 35 of Set 14|sassandra
# Processing Record 36 of Set 14|hearst
# Processing Record 37 of Set 14|santa cruz
# Processing Record 38 of Set 14|dongobesh
# Processing Record 39 of Set 14|mrirt
# City not found. Skipping...
# Processing Record 40 of Set 14|storforshei
# Processing Record 41 of Set 14|loandjili
# Processing Record 42 of Set 14|chokwe
# Processing Record 43 of Set 14|wattegama
# Processing Record 44 of Set 14|moshenskoye
# Processing Record 45 of Set 14|iskateley
# Processing Record 46 of Set 14|buchanan
# Processing Record 47 of Set 14|sedelnikovo
# City not found. Skipping...
# Processing Record 48 of Set 14|zruc nad sazavou
# Processing Record 49 of Set 14|skalistyy
# City not found. Skipping...
# Processing Record 50 of Set 14|port blair
# Processing Record 1 of Set 15|jatai
# Processing Record 2 of Set 15|pierrelatte
# Processing Record 3 of Set 15|mehamn
# Processing Record 4 of Set 15|savinka
# Processing Record 5 of Set 15|catamarca
# Processing Record 6 of Set 15|ornskoldsvik
# Processing Record 7 of Set 15|sao francisco
# Processing Record 8 of Set 15|lisakovsk
# Processing Record 9 of Set 15|abrau-dyurso
# Processing Record 10 of Set 15|phalia
# Processing Record 11 of Set 15|gubkinskiy
# Processing Record 12 of Set 15|kamyshlov
# Processing Record 13 of Set 15|cap malheureux
# Processing Record 14 of Set 15|kandi
# Processing Record 15 of Set 15|cabedelo
# Processing Record 16 of Set 15|lochgilphead
# Processing Record 17 of Set 15|staryy nadym
# Processing Record 18 of Set 15|tyukalinsk
# Processing Record 19 of Set 15|tromso
# Processing Record 20 of Set 15|nueva guinea
# Processing Record 21 of Set 15|tasbuget
# City not found. Skipping...
# Processing Record 22 of Set 15|nushki
# Processing Record 23 of Set 15|cozumel
# Processing Record 24 of Set 15|kalavad
# Processing Record 25 of Set 15|pobe
# Processing Record 26 of Set 15|puerto del rosario
# Processing Record 27 of Set 15|kunszentmiklos
# Processing Record 28 of Set 15|farah
# Processing Record 29 of Set 15|pombia
# Processing Record 30 of Set 15|nata
# Processing Record 31 of Set 15|edea
# Processing Record 32 of Set 15|semey
# Processing Record 33 of Set 15|santo amaro da imperatriz
# Processing Record 34 of Set 15|abyek
# Processing Record 35 of Set 15|lardos
# Processing Record 36 of Set 15|angra
# City not found. Skipping...
# Processing Record 37 of Set 15|tangara
# Processing Record 38 of Set 15|sesimbra
# Processing Record 39 of Set 15|cubuk
# Processing Record 40 of Set 15|itarema
# Processing Record 41 of Set 15|carbonia
# Processing Record 42 of Set 15|karabuk
# Processing Record 43 of Set 15|kikwit
# Processing Record 44 of Set 15|sioux lookout
# Processing Record 45 of Set 15|caravelas
# Processing Record 46 of Set 15|bafra
# Processing Record 47 of Set 15|casablanca
# Processing Record 48 of Set 15|gidam
# Processing Record 49 of Set 15|kadoma
# Processing Record 50 of Set 15|pasni
# Processing Record 1 of Set 16|belyy yar
# Processing Record 2 of Set 16|oussouye
# Processing Record 3 of Set 16|karaul
# City not found. Skipping...
# Processing Record 4 of Set 16|yarmouth
# Processing Record 5 of Set 16|kareli
# Processing Record 6 of Set 16|saryshagan
# City not found. Skipping...
# Processing Record 7 of Set 16|talara
# Processing Record 8 of Set 16|uvira
# Processing Record 9 of Set 16|lyngdal
# Processing Record 10 of Set 16|khash
# Processing Record 11 of Set 16|taoudenni
# Processing Record 12 of Set 16|bagn
# Processing Record 13 of Set 16|yining
# Processing Record 14 of Set 16|sao miguel do araguaia
# Processing Record 15 of Set 16|scottsburgh
# City not found. Skipping...
# Processing Record 16 of Set 16|rezina
# Processing Record 17 of Set 16|malinovoye ozero
# Processing Record 18 of Set 16|karasburg
# Processing Record 19 of Set 16|sosva
# Processing Record 20 of Set 16|champua
# Processing Record 21 of Set 16|campbellsville
# Processing Record 22 of Set 16|boende
# Processing Record 23 of Set 16|emirdag
# Processing Record 24 of Set 16|fonte boa
# Processing Record 25 of Set 16|saint-jean-de-maurienne
# Processing Record 26 of Set 16|pervomayskoye
# Processing Record 27 of Set 16|la palma
# Processing Record 28 of Set 16|abapo
# Processing Record 29 of Set 16|mimoso do sul
# Processing Record 30 of Set 16|shenkursk
# Processing Record 31 of Set 16|san andres
# Processing Record 32 of Set 16|sherbakul
# Processing Record 33 of Set 16|punta cardon
# Processing Record 34 of Set 16|biltine
# Processing Record 35 of Set 16|puerto madryn
# --------------------------
# Data retrieval complete
# --------------------------

# %%
# 7. Add data to a new DataFrame

city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0     Ushuaia      AR -54.8000 -68.3000     50.00        81          75
# 1  Nanortalik      GL  60.1432 -45.2371     27.03        91         100
# 2        Ibra      OM  22.6906  58.5334     54.32        75           0
# 3   Cape Town      ZA -33.9258  18.4232     64.99        82           0
# 4   Jamestown      US  42.0970 -79.2353     30.99       100          90
# 5   Kavaratti      IN  10.5669  72.6420     82.00        75           0
# 6       Sumbe      AO -11.2061  13.8437     73.40        85         100
# 7        Hofn      IS  64.2539 -15.2082     39.11        72         100
# 8        Chuy      UY -33.6971 -53.4616     61.86        81           0
# 9    Hermanus      ZA -34.4187  19.2345     66.00        82          12
#
#    Wind Speed Current Description
# 0       17.27       broken clouds
# 1        5.10     overcast clouds
# 2        1.95           clear sky
# 3        8.05           clear sky
# 4        9.22          light snow
# 5        9.51           clear sky
# 6        7.09     overcast clouds
# 7       13.22     overcast clouds
# 8        5.93           clear sky
# 9        5.99          few clouds

# %%
# 8. Export to CSV

# Create output csv file
output_csv_file = 'WeatherPy_Database.csv'

# Export the city data into a csv
city_data_df.to_csv(output_csv_file, index_label='City_ID')
